# %% [markdown]
# <a href="https://colab.research.google.com/github/yashh2910/severity/blob/main/yolov5_for_classification-trunk.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt  # install
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 15814, done.
# remote: Counting objects: 100% (45/45), done.
# remote: Compressing objects: 100% (43/43), done.
# remote: Total 15814 (delta 9), reused 22 (delta 2), pack-reused 15769
# Receiving objects: 100% (15814/15814), 14.59 MiB | 3.40 MiB/s, done.
# Resolving deltas: 100% (10823/10823), done.
# /content/yolov5
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.5/188.5 kB 4.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 605.9/605.9 kB 10.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 6.5 MB/s eta 0:00:00

# %%
# %cd /content/yolov5
# Out:
# /content/yolov5

# %%
# To mount your Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip -q '/content/drive/MyDrive/Severity/trunk yolo balanced.zip' -d /content

# %%
# !tar -xf /content/drive/MyDrive/frontbumper.tar.xz /content

# %%
# %cd ..
# %cd /content/yolov5/
# Out:
# /content
# /content/yolov5

# %%
import torch
print('Setup complete. Using torch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# Setup complete. Using torch 2.0.1+cu118 _CudaDeviceProperties(name='Tesla T4', major=7, minor=5, total_memory=15101MB, multi_processor_count=40)

# %%
# !python classify/train.py --model yolov5l-cls.pt --data '/content/trunk yolo balanced' --epochs 250 --pretrained weights/yolov5l-cls.pt --device 0
# Out:
# WARNING ⚠️ 'ultralytics.yolo.v8' is deprecated since '8.0.136' and will be removed in '8.1.0'. Please use 'ultralytics.models.yolo' instead.
# WARNING ⚠️ 'ultralytics.yolo.utils' is deprecated since '8.0.136' and will be removed in '8.1.0'. Please use 'ultralytics.utils' instead.
# Note this warning may be related to loading older models. You can update your model to current structure with:
#     import torch
#     ckpt = torch.load("model.pt")  # applies to both official and custom models
#     torch.save(ckpt, "updated-model.pt")
#
# classify/train: model=yolov5l-cls.pt, data=/content/trunk yolo balanced, epochs=250, batch_size=64, imgsz=224, nosave=False, cache=None, device=0, workers=8, project=runs/train-cls, name=exp, exist_ok=False, pretrained=weights/yolov5l-cls.pt, optimizer=Adam, lr0=0.001, decay=5e-05, label_smoothing=0.1, cutoff=None, dropout=None, verbose=False, seed=0, local_rank=-1
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# ...

# %%
# !python classify/val.py --weights /content/yolov5/runs/train-cls/exp/weights/best.pt --data '/content/trunk yolo balanced'
# Out:
# WARNING ⚠️ 'ultralytics.yolo.v8' is deprecated since '8.0.136' and will be removed in '8.1.0'. Please use 'ultralytics.models.yolo' instead.
# WARNING ⚠️ 'ultralytics.yolo.utils' is deprecated since '8.0.136' and will be removed in '8.1.0'. Please use 'ultralytics.utils' instead.
# Note this warning may be related to loading older models. You can update your model to current structure with:
#     import torch
#     ckpt = torch.load("model.pt")  # applies to both official and custom models
#     torch.save(ckpt, "updated-model.pt")
#
# classify/val: data=/content/trunk yolo balanced, weights=['/content/yolov5/runs/train-cls/exp/weights/best.pt'], batch_size=128, imgsz=224, device=, workers=8, verbose=True, project=runs/val-cls, name=exp, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 v7.0-193-g485da42 Python-3.10.6 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 215 layers, 25258819 parameters, 0 gradients, 68.3 GFLOPs
# ...
